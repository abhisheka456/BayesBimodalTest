# %%
# %load_ext autoreload

# %autoreload 2

# %matplotlib inline

# %%
import BayesBimodalTest as BBT
import numpy as np

N = 500
dataA = np.random.normal(2, 0.5, N/2)
dataB = np.random.normal(-2, 0.5, N/2)
data = np.concatenate([dataA, dataB])

# %%
test = BBT.BayesBimodalTest(data, nburn0=100, nburn=100, nprod=100, ntemps=1)

# %%
test.diagnostic_plot()

# %%
test.diagnostic_plot()
test.BayesFactor()
